# %% [markdown]
# # SwarmPRM  + Time

# %%
# %matplotlib inline

# %% [markdown]
# ## Road Map tests

# %%
from swarm_prm.envs.loader import MapLoader
from swarm_prm.solvers.swarm_prm.macro.gaussian_prm import GaussianPRM

# %%
fname = "../data/envs/map_2.yaml"
loader = MapLoader(fname)
loader.visualize("test_map")
map_instance = loader.get_map()
gaussian_prm = GaussianPRM(map_instance, None, 100, sampling_strategy="UNIFORM")
gaussian_prm.roadmap_construction()
# Out:
# /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:67: RuntimeWarning: overflow encountered in exp
#   return p * 2 * np.pi * sigma2 - np.exp(-t**2 / (2 * sigma2))
# /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:67: RuntimeWarning: divide by zero encountered in divide
#   return p * 2 * np.pi * sigma2 - np.exp(-t**2 / (2 * sigma2))
# ()
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 6
#       4 map_instance = loader.get_map()
#       5 gaussian_prm = GaussianPRM(map_instance, None, 100, sampling_strategy="UNIFORM")
# ----> 6 gaussian_prm.roadmap_construction()
#
# File /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:144, in GaussianPRM.roadmap_construction(self)
#     140 def roadmap_construction(self):
#     141     """
#     142         Build Gaussian PRM
#     143     """
# --> 144     self.sample_free_space() # sample node locations
#     145     self.load_instance() # adding problem instance nodes to roadmap
#     146     self.build_roadmap()
#
# File /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:165, in GaussianPRM.sample_free_space(self)
#     163 for obs in self.map.obstacles:
#     164     radius = min(radius, obs.get_dist(node))
# --> 165 g_node = GaussianGraphNode(node, None, radius=radius)
#     166 self.samples.append(node)
#     167 self.gaussian_nodes.append(g_node)
#
# File /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:25, in GaussianGraphNode.__init__(self, mean, covariance, type, alpha, radius)
#      23     self.radius = radius
#      24     self.alpha = alpha
# ---> 25     self.set_covariance()
#      27 elif type == "RANDOM":
#      28     super().__init__(mean, covariance)
#
# File /local-scratch/localhome/zma40/Desktop/project/SwarmPRM/src/swarm_prm/solvers/swarm_prm/macro/gaussian_prm.py:77, in GaussianGraphNode.set_covariance(self)
#      75 # Covariance matrix
#      76 print(sigma2_solution.shape)
# ---> 77 assert False
#
# AssertionError:

# %%
gaussian_prm.visualize_map("test_gprm")

# %% [markdown]
# test_gaussian_prm()
